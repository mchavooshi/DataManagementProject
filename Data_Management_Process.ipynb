# %% [markdown]
# ** This Jupyter Notebook provides an analysis of the "winequality-white" dataset, which can be found [here](https://github.com/jbrownlee/Datasets/blob/master/winequality-white.csv)

# %%
import pandas as pd
import numpy as np 

from pandas.plotting import scatter_matrix


from IPython.display import display


import matplotlib.pyplot as plt

# %% [markdown]
# # <font color='red'>Step 1</font>
#
# * **Import Data**

# %%
print('Loading data from file ...')  # load the data
dataset = pd.read_csv('winequality-white.csv')
print('done \n')
# Out:
# Loading data from file ...
# done

# %% [markdown]
# # <font color='red'>Step 2</font>
#
# * **Explore Data**

# %%
print('Sample rows from the dataset (top and bottom five):\n')
display(dataset.head(5))
print('\n')
display(dataset.tail(5))



#######################

dataset.info()
#######################


dataset.describe()
#######################


print('Summary of the dataset - Univariate statistics\n')   

display(dataset.describe(include='all'))


######################
print('Histograms:')
dataset.hist(figsize=(25, 15), bins=50)  # bins ~= sqrt(N)
plt.show()

print("\n")

print('Box plots:')
dataset.plot(figsize=(25, 15), kind='box', subplots=True, sharex=False, sharey=False)
plt.show()
# Out:
# Sample rows from the dataset (top and bottom five):
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# ...

# %% [markdown]
# # <font color='red'>Step 3</font>
#
# * **Cleaning Data**

# %%
#row_wise
data_duplicate = dataset.duplicated()
data_duplicate


df[data_duplicate]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2              0.23         0.32             8.5      0.058
# 5               8.1              0.28         0.40             6.9      0.050
# 7               7.0              0.27         0.36            20.7      0.045
# 8               6.3              0.30         0.34             1.6      0.049
# 20              6.2              0.66         0.48             1.2      0.029
# ...             ...               ...          ...             ...        ...
# 4828            6.4              0.23         0.35            10.3      0.042
# 4850            7.0              0.36         0.35             2.5      0.048
# 4851            6.4              0.33         0.44             8.9      0.055
# 4856            7.1              0.23         0.39            13.7      0.058
# 4880            6.6              0.34         0.40             8.1      0.046
#
# ...

# %%
data_dup = dataset.drop_duplicates()
data_dup
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 6               6.2              0.32         0.16             7.0      0.045
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
data_dup.dropna().shape
# Out:
# (3961, 12)

# %%
print('Removing rows with missing data ...')  # Make things simple
dataset = data_dup.dropna()  # default is to drop any row that contains at least one missing value
print('done \n')
# Out:
# Removing rows with missing data ...
# done
